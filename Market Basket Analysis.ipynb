# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import  association_rules
from pandas.plotting import parallel_coordinates
# Out:
# C:\Users\pga28\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
df = pd.read_csv(r"C:\Users\pga28\Downloads\archive (1).zip")

# %%
df.head()
# Out:
#    Unnamed: 0  Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  \
# 0           0  False   True   False   False   True   True  False       True
# 1           1  False  False   False   False  False  False  False      False
# 2           2   True  False    True   False  False   True  False       True
# 3           3  False  False    True    True  False   True  False      False
# 4           4   True   True   False   False  False  False  False      False
#
#    Kidney Beans   Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0         False  False   False  False   True    False    True       True
# 1         False   True   False  False  False    False   False      False
# 2         False   True   False  False  False    False    True       True
# 3         False   True    True   True  False    False   False      False
# 4         False  False   False  False  False    False   False      False

# %%
#for item in association_results:
    # first index of the inner list
    # Contains base item and add item
   # pair = item[0]
    #items = [x for x in pair]
    #print("Rule: " + items[0] + " -> " + items[1])
    # second index of the inner list
    #print("Support: " + str(item[1]))
    # third index of the list located at 0th position
    # of the third index of the inner list
    #print("Confidence: " + str(item[2][0][2]))
    #print("Lift: " + str(item[2][0][3]))
    #print(df.shape)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    999 non-null    int64
#  1   Apple         999 non-null    bool
#  2   Bread         999 non-null    bool
#  3   Butter        999 non-null    bool
#  4   Cheese        999 non-null    bool
#  5   Corn          999 non-null    bool
#  6   Dill          999 non-null    bool
#  7   Eggs          999 non-null    bool
#  8   Ice cream     999 non-null    bool
#  9   Kidney Beans  999 non-null    bool
#  10  Milk          999 non-null    bool
#  11  Nutmeg        999 non-null    bool
#  12  Onion         999 non-null    bool
#  13  Sugar         999 non-null    bool
#  14  Unicorn       999 non-null    bool
#  15  Yogurt        999 non-null    bool
#  16  chocolate     999 non-null    bool
# dtypes: bool(16), int64(1)
# memory usage: 23.5 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Apple           0
# Bread           0
# Butter          0
# Cheese          0
# Corn            0
# Dill            0
# Eggs            0
# Ice cream       0
# Kidney Beans    0
# Milk            0
# Nutmeg          0
# Onion           0
# Sugar           0
# Unicorn         0
# Yogurt          0
# chocolate       0
# dtype: int64

# %%
df.drop(df.columns[0],axis=1,inplace=True)

# %%
df
# Out:
#      Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  \
# 0    False   True   False   False   True   True  False       True
# 1    False  False   False   False  False  False  False      False
# 2     True  False    True   False  False   True  False       True
# 3    False  False    True    True  False   True  False      False
# 4     True   True   False   False  False  False  False      False
# ..     ...    ...     ...     ...    ...    ...    ...        ...
# 994  False   True   False   False  False  False   True      False
# 995   True  False   False   False   True  False  False      False
# 996   True  False   False   False   True   True  False      False
# 997  False  False    True    True   True  False   True       True
# 998  False  False   False   False  False  False  False      False
#
#      Kidney Beans   Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0           False  False   False  False   True    False    True       True
# 1           False   True   False  False  False    False   False      False
# 2           False   True   False  False  False    False    True       True
# 3           False   True    True   True  False    False   False      False
# 4           False  False   False  False  False    False   False      False
# ..            ...    ...     ...    ...    ...      ...     ...        ...
# 994         False  False   False  False  False     True   False       True
# 995          True   True    True  False  False    False    True      False
# 996         False  False   False  False   True    False   False       True
# 997          True  False    True  False   True    False    True       True
# 998         False   True   False  False  False    False   False       True
#
# [999 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Apple         999 non-null    bool
#  1   Bread         999 non-null    bool
#  2   Butter        999 non-null    bool
#  3   Cheese        999 non-null    bool
#  4   Corn          999 non-null    bool
#  5   Dill          999 non-null    bool
#  6   Eggs          999 non-null    bool
#  7   Ice cream     999 non-null    bool
#  8   Kidney Beans  999 non-null    bool
#  9   Milk          999 non-null    bool
#  10  Nutmeg        999 non-null    bool
#  11  Onion         999 non-null    bool
#  12  Sugar         999 non-null    bool
#  13  Unicorn       999 non-null    bool
#  14  Yogurt        999 non-null    bool
#  15  chocolate     999 non-null    bool
# dtypes: bool(16)
# memory usage: 15.7 KB

# %%
df.mean()
# Out:
# Apple           0.383383
# Bread           0.384384
# Butter          0.420420
# Cheese          0.404404
# Corn            0.407407
# Dill            0.398398
# Eggs            0.384384
# Ice cream       0.410410
# Kidney Beans    0.408408
# Milk            0.405405
# Nutmeg          0.401401
# Onion           0.403403
# Sugar           0.409409
# Unicorn         0.389389
# Yogurt          0.420420
# chocolate       0.421421
# dtype: float64

# %%
print(df['Apple'].sum())

print(df['Butter'].sum())
print(df.sum())
# Out:
# 383
# 420
# Apple           383
# Bread           384
# Butter          420
# Cheese          404
# Corn            407
# Dill            398
# Eggs            384
# Ice cream       410
# Kidney Beans    408
# Milk            405
# Nutmeg          401
# Onion           403
# Sugar           409
# Unicorn         389
# Yogurt          420
# chocolate       421
# dtype: int64

# %%
# Compute frequent itemsets using the Apriori algorithm
frequent_itemsets = apriori(df,
                            min_support = .03,
                            max_len = 4,
                            use_colnames = True)

# %%
frequent_itemsets.head(30)
# Out:
#      support               itemsets
# 0   0.383383                (Apple)
# 1   0.384384                (Bread)
# 2   0.420420               (Butter)
# 3   0.404404               (Cheese)
# 4   0.407407                 (Corn)
# 5   0.398398                 (Dill)
# 6   0.384384                 (Eggs)
# 7   0.410410            (Ice cream)
# 8   0.408408         (Kidney Beans)
# 9   0.405405                 (Milk)
# 10  0.401401               (Nutmeg)
# 11  0.403403                (Onion)
# 12  0.409409                (Sugar)
# 13  0.389389              (Unicorn)
# 14  0.420420               (Yogurt)
# 15  0.421421            (chocolate)
# 16  0.154154         (Bread, Apple)
# 17  0.188188        (Apple, Butter)
# 18  0.162162        (Apple, Cheese)
# 19  0.186186          (Apple, Corn)
# 20  0.179179          (Apple, Dill)
# 21  0.156156          (Apple, Eggs)
# 22  0.172172     (Ice cream, Apple)
# 23  0.176176  (Apple, Kidney Beans)
# 24  0.184184          (Apple, Milk)
# 25  0.172172        (Apple, Nutmeg)
# 26  0.167167         (Apple, Onion)
# 27  0.182182         (Apple, Sugar)
# 28  0.166166       (Unicorn, Apple)
# 29  0.187187        (Apple, Yogurt)

# %%
frequent_itemsets.tail(50)
# Out:
#        support                                    itemsets
# 2448  0.048048       (Sugar, Kidney Beans, Nutmeg, Yogurt)
# 2449  0.052052    (chocolate, Sugar, Kidney Beans, Nutmeg)
# 2450  0.046046     (Unicorn, Kidney Beans, Nutmeg, Yogurt)
# 2451  0.051051  (chocolate, Unicorn, Kidney Beans, Nutmeg)
# 2452  0.050050   (chocolate, Kidney Beans, Nutmeg, Yogurt)
# 2453  0.044044       (Unicorn, Onion, Sugar, Kidney Beans)
# 2454  0.045045        (Onion, Sugar, Kidney Beans, Yogurt)
# 2455  0.040040     (Onion, Sugar, Kidney Beans, chocolate)
# 2456  0.045045      (Unicorn, Onion, Kidney Beans, Yogurt)
# 2457  0.044044   (Unicorn, Onion, Kidney Beans, chocolate)
# 2458  0.047047    (Onion, Kidney Beans, chocolate, Yogurt)
# 2459  0.048048      (Unicorn, Sugar, Kidney Beans, Yogurt)
# 2460  0.051051   (Unicorn, Sugar, Kidney Beans, chocolate)
# 2461  0.051051    (Sugar, Kidney Beans, chocolate, Yogurt)
# 2462  0.041041  (Unicorn, Kidney Beans, chocolate, Yogurt)
# 2463  0.047047                (Onion, Sugar, Milk, Nutmeg)
# 2464  0.041041              (Unicorn, Onion, Milk, Nutmeg)
# 2465  0.046046               (Onion, Milk, Nutmeg, Yogurt)
# 2466  0.050050            (chocolate, Onion, Milk, Nutmeg)
# 2467  0.037037              (Unicorn, Sugar, Milk, Nutmeg)
# 2468  0.043043               (Sugar, Milk, Nutmeg, Yogurt)
# 2469  0.042042            (chocolate, Sugar, Milk, Nutmeg)
# 2470  0.041041             (Unicorn, Milk, Nutmeg, Yogurt)
# 2471  0.045045          (chocolate, Unicorn, Milk, Nutmeg)
# 2472  0.047047           (chocolate, Milk, Nutmeg, Yogurt)
# 2473  0.048048               (Unicorn, Onion, Sugar, Milk)
# 2474  0.046046                (Onion, Sugar, Milk, Yogurt)
# 2475  0.051051             (Onion, Sugar, Milk, chocolate)
# 2476  0.045045              (Unicorn, Onion, Milk, Yogurt)
# 2477  0.051051           (Unicorn, Onion, Milk, chocolate)
# 2478  0.050050            (Onion, Milk, chocolate, Yogurt)
# 2479  0.039039              (Unicorn, Sugar, Milk, Yogurt)
# 2480  0.046046           (Unicorn, Sugar, Milk, chocolate)
# 2481  0.049049            (Sugar, Milk, chocolate, Yogurt)
# 2482  0.045045          (Unicorn, Milk, chocolate, Yogurt)
# 2483  0.041041             (Unicorn, Onion, Sugar, Nutmeg)
# 2484  0.046046              (Onion, Sugar, Nutmeg, Yogurt)
# 2485  0.044044           (chocolate, Onion, Sugar, Nutmeg)
# 2486  0.044044            (Unicorn, Onion, Nutmeg, Yogurt)
# 2487  0.048048         (Unicorn, Onion, chocolate, Nutmeg)
# 2488  0.054054          (chocolate, Onion, Nutmeg, Yogurt)
# 2489  0.040040            (Unicorn, Sugar, Nutmeg, Yogurt)
# 2490  0.040040         (chocolate, Unicorn, Sugar, Nutmeg)
# 2491  0.045045          (chocolate, Sugar, Nutmeg, Yogurt)
# 2492  0.042042        (chocolate, Unicorn, Nutmeg, Yogurt)
# 2493  0.051051             (Unicorn, Onion, Sugar, Yogurt)
# 2494  0.052052          (Unicorn, Onion, Sugar, chocolate)
# 2495  0.048048           (Onion, Sugar, chocolate, Yogurt)
# 2496  0.048048         (Unicorn, Onion, chocolate, Yogurt)
# 2497  0.045045         (Unicorn, Sugar, chocolate, Yogurt)

# %%
#Compute all association rules for frequent_itemsets
rules = association_rules(frequent_itemsets,
                            metric = 'support',
                            min_threshold=0.2)

# %%
rules
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 0      (Ice cream)        (Butter)            0.410410            0.420420
# 1         (Butter)     (Ice cream)            0.420420            0.410410
# 2         (Butter)  (Kidney Beans)            0.420420            0.408408
# 3   (Kidney Beans)        (Butter)            0.408408            0.420420
# 4         (Butter)     (chocolate)            0.420420            0.421421
# 5      (chocolate)        (Butter)            0.421421            0.420420
# 6         (Cheese)  (Kidney Beans)            0.404404            0.408408
# 7   (Kidney Beans)        (Cheese)            0.408408            0.404404
# 8      (Ice cream)     (chocolate)            0.410410            0.421421
# 9      (chocolate)     (Ice cream)            0.421421            0.410410
# 10          (Milk)     (chocolate)            0.405405            0.421421
# 11     (chocolate)          (Milk)            0.421421            0.405405
#
#      support  confidence      lift  leverage  conviction
# 0   0.207207    0.504878  1.200889  0.034662    1.170579
# 1   0.207207    0.492857  1.200889  0.034662    1.162571
# 2   0.202202    0.480952  1.177626  0.030499    1.139764
# 3   0.202202    0.495098  1.177626  0.030499    1.147905
# 4   0.202202    0.480952  1.141262  0.025028    1.114693
# 5   0.202202    0.479810  1.141262  0.025028    1.114169
# 6   0.200200    0.495050  1.212143  0.035038    1.171583
# 7   0.200200    0.490196  1.212143  0.035038    1.168284
# 8   0.202202    0.492683  1.169098  0.029246    1.140467
# 9   0.202202    0.479810  1.169098  0.029246    1.133412
# 10  0.211211    0.520988  1.236263  0.040365    1.207857
# 11  0.211211    0.501188  1.236263  0.040365    1.192021

# %%
#
filtered_rules = rules[(rules['antecedent support'] > 0.02)&
                        (rules['consequent support'] >0.01) &
                        (rules['confidence'] > 0.4) &
                        (rules['lift'] > 1.0)]

# %% [markdown]
# filtered_rules

# %%
filtered_rules.sort_values('confidence',ascending=False)
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 10          (Milk)     (chocolate)            0.405405            0.421421
# 0      (Ice cream)        (Butter)            0.410410            0.420420
# 11     (chocolate)          (Milk)            0.421421            0.405405
# 3   (Kidney Beans)        (Butter)            0.408408            0.420420
# 6         (Cheese)  (Kidney Beans)            0.404404            0.408408
# 1         (Butter)     (Ice cream)            0.420420            0.410410
# 8      (Ice cream)     (chocolate)            0.410410            0.421421
# 7   (Kidney Beans)        (Cheese)            0.408408            0.404404
# 2         (Butter)  (Kidney Beans)            0.420420            0.408408
# 4         (Butter)     (chocolate)            0.420420            0.421421
# 5      (chocolate)        (Butter)            0.421421            0.420420
# 9      (chocolate)     (Ice cream)            0.421421            0.410410
#
#      support  confidence      lift  leverage  conviction
# 10  0.211211    0.520988  1.236263  0.040365    1.207857
# 0   0.207207    0.504878  1.200889  0.034662    1.170579
# 11  0.211211    0.501188  1.236263  0.040365    1.192021
# 3   0.202202    0.495098  1.177626  0.030499    1.147905
# 6   0.200200    0.495050  1.212143  0.035038    1.171583
# 1   0.207207    0.492857  1.200889  0.034662    1.162571
# 8   0.202202    0.492683  1.169098  0.029246    1.140467
# 7   0.200200    0.490196  1.212143  0.035038    1.168284
# 2   0.202202    0.480952  1.177626  0.030499    1.139764
# 4   0.202202    0.480952  1.141262  0.025028    1.114693
# 5   0.202202    0.479810  1.141262  0.025028    1.114169
# 9   0.202202    0.479810  1.169098  0.029246    1.133412

# %%
filtered_rules.sort_values('support',ascending=False)
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 10          (Milk)     (chocolate)            0.405405            0.421421
# 11     (chocolate)          (Milk)            0.421421            0.405405
# 0      (Ice cream)        (Butter)            0.410410            0.420420
# 1         (Butter)     (Ice cream)            0.420420            0.410410
# 2         (Butter)  (Kidney Beans)            0.420420            0.408408
# 3   (Kidney Beans)        (Butter)            0.408408            0.420420
# 4         (Butter)     (chocolate)            0.420420            0.421421
# 5      (chocolate)        (Butter)            0.421421            0.420420
# 8      (Ice cream)     (chocolate)            0.410410            0.421421
# 9      (chocolate)     (Ice cream)            0.421421            0.410410
# 6         (Cheese)  (Kidney Beans)            0.404404            0.408408
# 7   (Kidney Beans)        (Cheese)            0.408408            0.404404
#
#      support  confidence      lift  leverage  conviction
# 10  0.211211    0.520988  1.236263  0.040365    1.207857
# 11  0.211211    0.501188  1.236263  0.040365    1.192021
# 0   0.207207    0.504878  1.200889  0.034662    1.170579
# 1   0.207207    0.492857  1.200889  0.034662    1.162571
# 2   0.202202    0.480952  1.177626  0.030499    1.139764
# 3   0.202202    0.495098  1.177626  0.030499    1.147905
# 4   0.202202    0.480952  1.141262  0.025028    1.114693
# 5   0.202202    0.479810  1.141262  0.025028    1.114169
# 8   0.202202    0.492683  1.169098  0.029246    1.140467
# 9   0.202202    0.479810  1.169098  0.029246    1.133412
# 6   0.200200    0.495050  1.212143  0.035038    1.171583
# 7   0.200200    0.490196  1.212143  0.035038    1.168284

# %%
# Generate scatterplot confidence versus support
fig , ax = plt.subplots()
ax.scatter(x = "support", y = "confidence", data = filtered_rules)
plt.show()

# %%
 filtered_rules =rules[(rules['antecedent support'] > 0.02)&
                        (rules['consequent support'] >0.01) &
                        (rules['confidence'] > 0.45) &
                        (rules['lift'] > 1.0)]

# %%
filtered_rules
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 0      (Ice cream)        (Butter)            0.410410            0.420420
# 1         (Butter)     (Ice cream)            0.420420            0.410410
# 2         (Butter)  (Kidney Beans)            0.420420            0.408408
# 3   (Kidney Beans)        (Butter)            0.408408            0.420420
# 4         (Butter)     (chocolate)            0.420420            0.421421
# 5      (chocolate)        (Butter)            0.421421            0.420420
# 6         (Cheese)  (Kidney Beans)            0.404404            0.408408
# 7   (Kidney Beans)        (Cheese)            0.408408            0.404404
# 8      (Ice cream)     (chocolate)            0.410410            0.421421
# 9      (chocolate)     (Ice cream)            0.421421            0.410410
# 10          (Milk)     (chocolate)            0.405405            0.421421
# 11     (chocolate)          (Milk)            0.421421            0.405405
#
#      support  confidence      lift  leverage  conviction
# 0   0.207207    0.504878  1.200889  0.034662    1.170579
# 1   0.207207    0.492857  1.200889  0.034662    1.162571
# 2   0.202202    0.480952  1.177626  0.030499    1.139764
# 3   0.202202    0.495098  1.177626  0.030499    1.147905
# 4   0.202202    0.480952  1.141262  0.025028    1.114693
# 5   0.202202    0.479810  1.141262  0.025028    1.114169
# 6   0.200200    0.495050  1.212143  0.035038    1.171583
# 7   0.200200    0.490196  1.212143  0.035038    1.168284
# 8   0.202202    0.492683  1.169098  0.029246    1.140467
# 9   0.202202    0.479810  1.169098  0.029246    1.133412
# 10  0.211211    0.520988  1.236263  0.040365    1.207857
# 11  0.211211    0.501188  1.236263  0.040365    1.192021

# %%
# Generate scatterplot confidence versus support

sns.scatterplot(x = "support", y = "confidence", size= 'leverage',data = filtered_rules)
plt.legend(bbox_to_anchor= (1.02, 1), loc='upper left',)
plt.show()

# %%
# add extra another rule where support more than 0.2 for given itemset
filtered_rules = rules[(rules['antecedent support'] > 0.02)&
                        (rules['consequent support'] >0.01) &
                        (rules['confidence'] > 0.45) &
                        (rules['lift'] > 1.0)&
                        (rules['support']>0.195)]

# %%
filtered_rules
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 0      (Ice cream)        (Butter)            0.410410            0.420420
# 1         (Butter)     (Ice cream)            0.420420            0.410410
# 2         (Butter)  (Kidney Beans)            0.420420            0.408408
# 3   (Kidney Beans)        (Butter)            0.408408            0.420420
# 4         (Butter)     (chocolate)            0.420420            0.421421
# 5      (chocolate)        (Butter)            0.421421            0.420420
# 6         (Cheese)  (Kidney Beans)            0.404404            0.408408
# 7   (Kidney Beans)        (Cheese)            0.408408            0.404404
# 8      (Ice cream)     (chocolate)            0.410410            0.421421
# 9      (chocolate)     (Ice cream)            0.421421            0.410410
# 10          (Milk)     (chocolate)            0.405405            0.421421
# 11     (chocolate)          (Milk)            0.421421            0.405405
#
#      support  confidence      lift  leverage  conviction
# 0   0.207207    0.504878  1.200889  0.034662    1.170579
# 1   0.207207    0.492857  1.200889  0.034662    1.162571
# 2   0.202202    0.480952  1.177626  0.030499    1.139764
# 3   0.202202    0.495098  1.177626  0.030499    1.147905
# 4   0.202202    0.480952  1.141262  0.025028    1.114693
# 5   0.202202    0.479810  1.141262  0.025028    1.114169
# 6   0.200200    0.495050  1.212143  0.035038    1.171583
# 7   0.200200    0.490196  1.212143  0.035038    1.168284
# 8   0.202202    0.492683  1.169098  0.029246    1.140467
# 9   0.202202    0.479810  1.169098  0.029246    1.133412
# 10  0.211211    0.520988  1.236263  0.040365    1.207857
# 11  0.211211    0.501188  1.236263  0.040365    1.192021

# %%
def rules_to_coordinates(rules):
    rules['antecedent'] = rules['antecedents'].apply(lambda antecedent:list(antecedent)[0])
    rules['consequent'] = rules['consequents'].apply(lambda consequent:list(consequent)[0])
    rules['rule'] = rules.index
    return rules[['antecedent','consequent','rule']]

# %%
from pandas.plotting import parallel_coordinates
# Convert rules into coordinates suitable for use in a parallel coordinates plot
coords = rules_to_coordinates(filtered_rules)
# Generate parallel coordinates plot
plt.figure(figsize=(6,10))
parallel_coordinates(coords, 'rule',colormap = 'ocean')
plt.legend([])
plt.show()

# %%
df['Apple'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
for item in filtered_rules:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " > " + items[0])
    # second index of the inner list
    print("Support: " + str(item[1]))
    # third index of the list located at 0th position
    # of the third index of the inner list
    print("Confidence: " + str(item[0][0][0]))
    print("Lift: " + str(item[0][0][0]))
    print("-----------------------------------------------------")
# Out:
# Rule: a > a
# Support: n
# Confidence: a
# Lift: a
# -----------------------------------------------------
# Rule: c > c
# Support: o
# Confidence: c
# Lift: c
# -----------------------------------------------------
# Rule: a > a
# Support: n
# Confidence: a
# Lift: a
# -----------------------------------------------------
# Rule: c > c
# Support: o
# Confidence: c
# Lift: c
# -----------------------------------------------------
# Rule: s > s
# Support: u
# Confidence: s
# Lift: s
# -----------------------------------------------------
# Rule: c > c
# Support: o
# Confidence: c
# Lift: c
# -----------------------------------------------------
# Rule: l > l
# Support: i
# Confidence: l
# Lift: l
# -----------------------------------------------------
# Rule: l > l
# Support: e
# Confidence: l
# Lift: l
# -----------------------------------------------------
# Rule: c > c
# Support: o
# Confidence: c
# Lift: c
# -----------------------------------------------------
# Rule: a > a
# Support: n
# Confidence: a
# Lift: a
# -----------------------------------------------------
# Rule: c > c
# Support: o
# Confidence: c
# Lift: c
# -----------------------------------------------------
# Rule: r > r
# Support: u
# Confidence: r
# Lift: r
# -----------------------------------------------------
